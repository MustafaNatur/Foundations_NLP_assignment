# %% [markdown]
# # Assignment: Training and Evaluating a Small Transformer Language Model
#
# ## 1. Setup
#
# ### 1.1 Clone the repository

# %%
# !git clone https://github.com/karpathy/nanoGPT.git
# %cd nanoGPT
# Out:
# f:\V.I.P\Uni\Foundations_NLP_assignment\nanoGPT
# fatal: destination path 'nanoGPT' already exists and is not an empty directory.

# %% [markdown]
# ### 1.2 Install dependencies

# %%
# !pip install torch numpy transformers datasets tiktoken wandb tqdm matplotlib
# Out:
# Requirement already satisfied: torch in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.11.0)
# Requirement already satisfied: numpy in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.5)
# Requirement already satisfied: transformers in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (5.5.4)
# Requirement already satisfied: datasets in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.8.4)
# Requirement already satisfied: tiktoken in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.12.0)
# Requirement already satisfied: wandb in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.26.0)
# Requirement already satisfied: tqdm in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.67.3)
# Requirement already satisfied: matplotlib in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.7)
# Requirement already satisfied: filelock in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.28.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (1.11.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.10)
# Requirement already satisfied: h11>=0.16 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from datasets) (3.0.2)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from datasets) (2.33.1)
# Requirement already satisfied: xxhash in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: click>=8.0.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wandb) (8.3.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wandb) (3.1.46)
# Requirement already satisfied: platformdirs in C:\Users\timne\AppData\Roaming\Python\Python313\site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wandb) (7.34.1)
# Requirement already satisfied: pydantic<3 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wandb) (2.11.9)
# Requirement already satisfied: sentry-sdk>=2.0.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from wandb) (2.58.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: colorama in C:\Users\timne\AppData\Roaming\Python\Python313\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\timne\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# Requirement already satisfied: six>=1.5 in C:\Users\timne\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: tzdata in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\timne\AppData\Roaming\Python\Python313\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\timne\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)

# %% [markdown]
# ### 1.3 Prepare the dataset

# %%
# !cd data/shakespeare_char
# !python prepare.py
# !cd ../..
# Out:
# python: can't open file 'f:\\V.I.P\\Uni\\Foundations_NLP_assignment\\nanoGPT\\prepare.py': [Errno 2] No such file or directory

# %% [markdown]
# ## 2. Baseline Training Run

# %%
# Baseline configuration
out_dir = 'out-shakespeare-baseline'
eval_interval = 250
eval_iters = 200
log_interval = 10

always_save_checkpoint = False

wandb_log = False
wandb_project = 'nanoGPT-assignment'
wandb_run_name = 'baseline'

dataset = 'shakespeare_char'
gradient_accumulation_steps = 1
batch_size = 64
block_size = 256

n_layer = 6
n_head = 6
n_embd = 384
dropout = 0.2

learning_rate = 1e-3
max_iters = 5000
lr_decay_iters = 5000
min_lr = 1e-4
beta2 = 0.99

warmup_iters = 100
weight_decay = 1e-1

device = 'cuda' # change to 'cuda' if you have a GPU
compile = False # set True only on Linux with GPU

# %% [markdown]
# Run the baseline:

# %%
python train.py config/train_shakespeare_char_baseline.py

# %% [markdown]
# Training should take approximately 10–20 minutes on a modern laptop CPU.

# %% [markdown]
# ### Generate text from the trained model

# %%
python sample.py --out_dir=out-shakespeare-baseline \ --device=cpu --num_samples=3 --max_new
# Out:
#   Cell In[2], line 1
#     python sample.py --out_dir=out-shakespeare-baseline \ --device=cpu --num_samples=3 --max_new
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. Hyperparameter Experiments
